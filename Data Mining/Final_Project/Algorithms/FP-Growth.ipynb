# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder 
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth

# %%
dataset = [['mbalvi', '5 kilo meters', 'remember to Walk'], ['mbalvi', 'remember to Walk'],
['Divergent', 'Hassan','remember to Walk'], ['mbalvi', 'Five kilo meters'],
['Divergent','Hassan']] 
te = TransactionEncoder()
te_array = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_array, columns=te.columns_)

# %%
df
# Out:
#    5 kilo meters  Divergent  Five kilo meters  Hassan  mbalvi  \
# 0           True      False             False   False    True
# 1          False      False             False   False    True
# 2          False       True             False    True   False
# 3          False      False              True   False    True
# 4          False       True             False    True   False
#
#    remember to Walk
# 0              True
# 1              True
# 2              True
# 3             False
# 4             False

# %%
dataset
# Out:
# [['mbalvi', '5 kilo meters', 'remember to Walk'],
#  ['mbalvi', 'remember to Walk'],
#  ['Divergent', 'Hassan', 'remember to Walk'],
#  ['mbalvi', 'Five kilo meters'],
#  ['Divergent', 'Hassan']]

# %%
frequent_itemsets_fp=fpgrowth(df, min_support=0.02, use_colnames=True)

frequent_itemsets_fp=fpgrowth(df, min_support=0.02, use_colnames=True)

# %%
rules_fp = association_rules(frequent_itemsets_fp, metric="confidence", min_threshold=0.8)

# %%
rules_fp
# Out:
#                          antecedents                 consequents  \
# 0                    (5 kilo meters)                    (mbalvi)
# 1                    (5 kilo meters)          (remember to Walk)
# 2  (remember to Walk, 5 kilo meters)                    (mbalvi)
# 3            (mbalvi, 5 kilo meters)          (remember to Walk)
# 4                    (5 kilo meters)  (remember to Walk, mbalvi)
# 5                           (Hassan)                 (Divergent)
# 6                        (Divergent)                    (Hassan)
# 7         (remember to Walk, Hassan)                 (Divergent)
# 8      (remember to Walk, Divergent)                    (Hassan)
# 9                 (Five kilo meters)                    (mbalvi)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0                 0.2                 0.6      0.2         1.0  1.666667
# 1                 0.2                 0.6      0.2         1.0  1.666667
# 2                 0.2                 0.6      0.2         1.0  1.666667
# 3                 0.2                 0.6      0.2         1.0  1.666667
# 4                 0.2                 0.4      0.2         1.0  2.500000
# 5                 0.4                 0.4      0.4         1.0  2.500000
# 6                 0.4                 0.4      0.4         1.0  2.500000
# 7                 0.2                 0.4      0.2         1.0  2.500000
# 8                 0.2                 0.4      0.2         1.0  2.500000
# 9                 0.2                 0.6      0.2         1.0  1.666667
#
#    leverage  conviction  zhangs_metric
# 0      0.08         inf           0.50
# 1      0.08         inf           0.50
# 2      0.08         inf           0.50
# 3      0.08         inf           0.50
# 4      0.12         inf           0.75
# 5      0.24         inf           1.00
# 6      0.24         inf           1.00
# 7      0.12         inf           0.75
# 8      0.12         inf           0.75
# 9      0.08         inf           0.50

# %%
frequent_itemsets_fp
# Out:
#     support                                   itemsets
# 0       0.6                         (remember to Walk)
# 1       0.6                                   (mbalvi)
# 2       0.2                            (5 kilo meters)
# 3       0.4                                   (Hassan)
# 4       0.4                                (Divergent)
# 5       0.2                         (Five kilo meters)
# 6       0.4                 (remember to Walk, mbalvi)
# 7       0.2                    (mbalvi, 5 kilo meters)
# 8       0.2          (remember to Walk, 5 kilo meters)
# 9       0.2  (remember to Walk, mbalvi, 5 kilo meters)
# 10      0.2                 (remember to Walk, Hassan)
# 11      0.4                        (Hassan, Divergent)
# 12      0.2              (remember to Walk, Divergent)
# 13      0.2      (remember to Walk, Hassan, Divergent)
# 14      0.2                 (mbalvi, Five kilo meters)
